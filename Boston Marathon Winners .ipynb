# %%
import pandas as pd

# %%
df1=pd.read_csv('file:///C:/Users/21.%20Technology/Downloads/Mens_Boston_Marathon_Winners.csv')
df1.head()
# Out:
#      Year              Winner        Country      Time  Distance (Miles)  \
# 0  1897.0      John McDermott  United States  02:55:10              24.5
# 1  1898.0    Ronald MacDonald         Canada  02:42:00              24.5
# 2  1899.0  Lawrence Brignolia  United States  02:54:38              24.5
# 3  1900.0        Jack Caffery         Canada  02:39:44              24.5
# 4  1901.0        Jack Caffery         Canada  02:29:23              24.5
#
#    Distance (KM)
# 0           39.4
# 1           39.4
# 2           39.4
# 3           39.4
# 4           39.4

# %%
df2=pd.read_csv('file:///C:/Users/21.%20Technology/Downloads/Womens_Boston_Marathon_Winners.csv')
df2.head()
# Out:
#      Year           Winner        Country     Time  Distance (Miles)  \
# 0  1966.0       Bobbi Gibb  United States  3:21:40              26.2
# 1  1967.0       Bobbi Gibb  United States  3:27:17              26.2
# 2  1968.0       Bobbi Gibb  United States  3:30:00              26.2
# 3  1969.0  Sara Mae Berman  United States  3:22:46              26.2
# 4  1970.0  Sara Mae Berman  United States  3:05:07              26.2
#
#    Distance (KM)
# 0           42.2
# 1           42.2
# 2           42.2
# 3           42.2
# 4           42.2

# %%
df=df1.append(df2)
# Out:
# C:\Users\21. Technology\AppData\Local\Temp\ipykernel_6904\2456558213.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df1.append(df2)

# %%
df.head()
# Out:
#      Year              Winner        Country      Time  Distance (Miles)  \
# 0  1897.0      John McDermott  United States  02:55:10              24.5
# 1  1898.0    Ronald MacDonald         Canada  02:42:00              24.5
# 2  1899.0  Lawrence Brignolia  United States  02:54:38              24.5
# 3  1900.0        Jack Caffery         Canada  02:39:44              24.5
# 4  1901.0        Jack Caffery         Canada  02:29:23              24.5
#
#    Distance (KM)
# 0           39.4
# 1           39.4
# 2           39.4
# 3           39.4
# 4           39.4

# %%
df.tail()
# Out:
#       Year             Winner        Country     Time  Distance (Miles)  \
# 52  2018.0     Desiree Linden  United States  2:39:54              26.2
# 53  2019.0    Worknesh Degefa       Ethiopia  2:23:31              26.2
# 54     NaN                NaN            NaN      NaN              26.2
# 55  2021.0      Edna Kiplagat          Kenya  2:25:09              26.2
# 56  2022.0  Peres Jepchirchir          Kenya  2:21:02              26.2
#
#     Distance (KM)
# 52           42.2
# 53           42.2
# 54           42.2
# 55           42.2
# 56           42.2

# %%
df.sample(5)
# Out:
#       Year                  Winner         Country      Time  \
# 40  1937.0            Walter Young          Canada  02:33:20
# 88  1985.0             Geoff Smith  United Kingdom  02:14:05
# 61  1958.0          Franjo Mihalic      Yugoslavia  02:25:54
# 33  1999.0             Fatuma Roba        Ethiopia   2:23:25
# 67  1964.0  Aurèle Vandendriessche         Belgium  02:19:59
#
#     Distance (Miles)  Distance (KM)
# 40              26.2           42.2
# 88              26.2           42.2
# 61              26.2           42.2
# 33              26.2           42.2
# 67              26.2           42.2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 183 entries, 0 to 56
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Year              180 non-null    float64
#  1   Winner            180 non-null    object
#  2   Country           180 non-null    object
#  3   Time              180 non-null    object
#  4   Distance (Miles)  181 non-null    float64
#  5   Distance (KM)     181 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 10.0+ KB

# %%
df.infer_objects()
# Out:
#       Year              Winner        Country      Time  Distance (Miles)  \
# 0   1897.0      John McDermott  United States  02:55:10              24.5
# 1   1898.0    Ronald MacDonald         Canada  02:42:00              24.5
# 2   1899.0  Lawrence Brignolia  United States  02:54:38              24.5
# 3   1900.0        Jack Caffery         Canada  02:39:44              24.5
# 4   1901.0        Jack Caffery         Canada  02:29:23              24.5
# ..     ...                 ...            ...       ...               ...
# 52  2018.0      Desiree Linden  United States   2:39:54              26.2
# 53  2019.0     Worknesh Degefa       Ethiopia   2:23:31              26.2
# 54     NaN                 NaN            NaN       NaN              26.2
# 55  2021.0       Edna Kiplagat          Kenya   2:25:09              26.2
# 56  2022.0   Peres Jepchirchir          Kenya   2:21:02              26.2
#
#     Distance (KM)
# 0            39.4
# 1            39.4
# 2            39.4
# ...

# %%
df.isnull().sum()
# Out:
# Year                3
# Winner              3
# Country             3
# Time                3
# Distance (Miles)    2
# Distance (KM)       2
# dtype: int64

# %%
df.shape
# Out:
# (183, 6)

# %%
df.describe()
# Out:
#               Year  Distance (Miles)  Distance (KM)
# count   180.000000        181.000000     181.000000
# mean   1969.983333         25.937569      41.767956
# std      35.148126          0.597237       0.983232
# min    1897.000000         24.500000      39.400000
# 25%    1942.750000         26.200000      42.200000
# 50%    1976.500000         26.200000      42.200000
# 75%    1999.000000         26.200000      42.200000
# max    2022.000000         26.200000      42.200000

# %%
df.corr()
# Out:
# C:\Users\21. Technology\AppData\Local\Temp\ipykernel_6904\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                       Year  Distance (Miles)  Distance (KM)
# Year              1.000000           0.72433       0.725056
# Distance (Miles)  0.724330           1.00000       0.999980
# Distance (KM)     0.725056           0.99998       1.000000

# %%
df.corr().describe().T
# Out:
# C:\Users\21. Technology\AppData\Local\Temp\ipykernel_6904\427718416.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr().describe().T
#                   count      mean       std       min       25%       50%  \
# Year                3.0  0.816462  0.158949  0.724330  0.724693  0.725056
# Distance (Miles)    3.0  0.908103  0.159152  0.724330  0.862155  0.999980
# Distance (KM)       3.0  0.908345  0.158733  0.725056  0.862518  0.999980
#
#                        75%  max
# Year              0.862528  1.0
# Distance (Miles)  0.999990  1.0
# Distance (KM)     0.999990  1.0

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df[df.duplicated()]
# Out:
#      Year Winner Country Time  Distance (Miles)  Distance (KM)
# 123   NaN    NaN     NaN  NaN               NaN            NaN

# %%
df=df.drop_duplicates()

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Year, Winner, Country, Time, Distance (Miles), Distance (KM)]
# Index: []

# %%
df.shape
# Out:
# (182, 6)

# %%
df.isnull().sum()
# Out:
# Year                2
# Winner              2
# Country             2
# Time                2
# Distance (Miles)    1
# Distance (KM)       1
# dtype: int64

# %%
df=df.fillna(df.mean())
# Out:
# C:\Users\21. Technology\AppData\Local\Temp\ipykernel_6904\3358723971.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df=df.fillna(df.mean())

# %%
df.head()
# Out:
#      Year              Winner        Country      Time  Distance (Miles)  \
# 0  1897.0      John McDermott  United States  02:55:10              24.5
# 1  1898.0    Ronald MacDonald         Canada  02:42:00              24.5
# 2  1899.0  Lawrence Brignolia  United States  02:54:38              24.5
# 3  1900.0        Jack Caffery         Canada  02:39:44              24.5
# 4  1901.0        Jack Caffery         Canada  02:29:23              24.5
#
#    Distance (KM)
# 0           39.4
# 1           39.4
# 2           39.4
# 3           39.4
# 4           39.4

# %%
df.isnull().sum()
# Out:
# Year                0
# Winner              2
# Country             2
# Time                2
# Distance (Miles)    0
# Distance (KM)       0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Year                0
# Winner              2
# Country             2
# Time                2
# Distance (Miles)    0
# Distance (KM)       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 182 entries, 0 to 56
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Year              182 non-null    float64
#  1   Winner            180 non-null    object
#  2   Country           180 non-null    object
#  3   Time              180 non-null    object
#  4   Distance (Miles)  182 non-null    float64
#  5   Distance (KM)     182 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 10.0+ KB

# %%
df['Winner'].head()
# Out:
# 0        John McDermott
# 1      Ronald MacDonald
# 2    Lawrence Brignolia
# 3          Jack Caffery
# 4          Jack Caffery
# Name: Winner, dtype: object

# %%
df['Country'].head()
# Out:
# 0    United States
# 1           Canada
# 2    United States
# 3           Canada
# 4           Canada
# Name: Country, dtype: object

# %%
df.mean()
# Out:
# C:\Users\21. Technology\AppData\Local\Temp\ipykernel_6904\3698961737.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Year                1969.983333
# Distance (Miles)      25.937569
# Distance (KM)         41.767956
# dtype: float64

# %%
df.median()
# Out:
# C:\Users\21. Technology\AppData\Local\Temp\ipykernel_6904\530051474.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# Year                1976.0
# Distance (Miles)      26.2
# Distance (KM)         42.2
# dtype: float64

# %%
df.mode()
# Out:
#            Year          Winner        Country      Time  Distance (Miles)  \
# 0   1966.000000  Clarence DeMar  United States  02:10:34              26.2
# 1   1967.000000             NaN            NaN  02:25:14               NaN
# 2   1968.000000             NaN            NaN  02:31:50               NaN
# 3   1969.000000             NaN            NaN   2:24:55               NaN
# 4   1969.983333             NaN            NaN   2:26:11               NaN
# 5   1970.000000             NaN            NaN       NaN               NaN
# 6   1971.000000             NaN            NaN       NaN               NaN
# 7   1972.000000             NaN            NaN       NaN               NaN
# 8   1973.000000             NaN            NaN       NaN               NaN
# 9   1974.000000             NaN            NaN       NaN               NaN
# 10  1975.000000             NaN            NaN       NaN               NaN
# ...

# %%
df.skew()
# Out:
# C:\Users\21. Technology\AppData\Local\Temp\ipykernel_6904\1665899112.py:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.skew()
# Year               -0.470414
# Distance (Miles)   -1.974454
# Distance (KM)      -1.977538
# dtype: float64

# %%
for i in df.columns:
    print(f'unique values in column "{i}" is\n {df[i].value_counts()}')
    print('--------------------------------------------------------------')
# Out:
# unique values in column "Year" is
#  2022.0    2
# 1979.0    2
# 1991.0    2
# 1990.0    2
# 1989.0    2
#          ..
# 1934.0    1
# 1933.0    1
# 1932.0    1
# 1931.0    1
# 1959.0    1
# Name: Year, Length: 125, dtype: int64
# --------------------------------------------------------------
# unique values in column "Winner" is
#  Clarence DeMar               7
# Catherine Ndereba            4
# Robert Kipkoech Cheruiyot    4
# Bill Rodgers                 4
# Gérard Côté                  4
#                             ..
# Veikko Karvonen              1
# Keizo Yamada                 1
# Mateo Flores                 1
# Shigeki Tanaka               1
# Peres Jepchirchir            1
# Name: Winner, Length: 129, dtype: int64
# --------------------------------------------------------------
# unique values in column "Country" is
#  United States     59
# Kenya             38
# Canada            17
# Ethiopia          14
# Japan              9
# Finland            7
# ...

# %%
object_col=[]
num_col=[]
for i in df.columns:
    if df[i].dtype=='object':
        object_col.append(i)
    else:
        num_col.append(i)

# %%
num_col
# Out:
# ['Year', 'Distance (Miles)', 'Distance (KM)']

# %%
object_col
# Out:
# ['Winner', 'Country', 'Time']

# %%
df.head()
# Out:
#      Year              Winner        Country      Time  Distance (Miles)  \
# 0  1897.0      John McDermott  United States  02:55:10              24.5
# 1  1898.0    Ronald MacDonald         Canada  02:42:00              24.5
# 2  1899.0  Lawrence Brignolia  United States  02:54:38              24.5
# 3  1900.0        Jack Caffery         Canada  02:39:44              24.5
# 4  1901.0        Jack Caffery         Canada  02:29:23              24.5
#
#    Distance (KM)
# 0           39.4
# 1           39.4
# 2           39.4
# 3           39.4
# 4           39.4

# %%
df.isnull().sum()
# Out:
# Year                0
# Winner              2
# Country             2
# Time                2
# Distance (Miles)    0
# Distance (KM)       0
# dtype: int64

# %%
df['Hour']=df['Time'].str.split(':').str[0]
df['Minutes']=df['Time'].str.split(':').str[1]
df['Second']=df['Time'].str.split(':').str[2]

# %%
df.head()
# Out:
#      Year              Winner        Country      Time  Distance (Miles)  \
# 0  1897.0      John McDermott  United States  02:55:10              24.5
# 1  1898.0    Ronald MacDonald         Canada  02:42:00              24.5
# 2  1899.0  Lawrence Brignolia  United States  02:54:38              24.5
# 3  1900.0        Jack Caffery         Canada  02:39:44              24.5
# 4  1901.0        Jack Caffery         Canada  02:29:23              24.5
#
#    Distance (KM) Hour Minutes Second
# 0           39.4   02      55     10
# 1           39.4   02      42     00
# 2           39.4   02      54     38
# 3           39.4   02      39     44
# 4           39.4   02      29     23

# %%
df=df.drop(['Time'],axis=1)

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# Year                0
# Winner              0
# Country             0
# Distance (Miles)    0
# Distance (KM)       0
# Hour                0
# Minutes             0
# Second              0
# dtype: int64

# %%
df.head()
# Out:
#      Year              Winner        Country  Distance (Miles)  Distance (KM)  \
# 0  1897.0      John McDermott  United States              24.5           39.4
# 1  1898.0    Ronald MacDonald         Canada              24.5           39.4
# 2  1899.0  Lawrence Brignolia  United States              24.5           39.4
# 3  1900.0        Jack Caffery         Canada              24.5           39.4
# 4  1901.0        Jack Caffery         Canada              24.5           39.4
#
#   Hour Minutes Second
# 0   02      55     10
# 1   02      42     00
# 2   02      54     38
# 3   02      39     44
# 4   02      29     23

# %%
df['Year'] = df['Year'].astype(str)

# %%
df.dtypes
# Out:
# Year                 object
# Winner               object
# Country              object
# Distance (Miles)    float64
# Distance (KM)       float64
# Hour                 object
# Minutes              object
# Second               object
# dtype: object

# %%
df['year']=df['Year'].str.split('.').str[0]

# %%
df.head()
# Out:
#                Winner        Country  Distance (Miles)  Distance (KM) Hour  \
# 0      John McDermott  United States              24.5           39.4   02
# 1    Ronald MacDonald         Canada              24.5           39.4   02
# 2  Lawrence Brignolia  United States              24.5           39.4   02
# 3        Jack Caffery         Canada              24.5           39.4   02
# 4        Jack Caffery         Canada              24.5           39.4   02
#
#   Minutes Second  year
# 0      55     10  1897
# 1      42     00  1898
# 2      54     38  1899
# 3      39     44  1900
# 4      29     23  1901

# %%
df=df.drop(['Year'],axis=1)

# %%
df['Hour'] = df['Hour'].astype(int)
df['Minutes'] = df['Minutes'].astype(int)
df['Second'] = df['Second'].astype(int)
df['year'] = df['year'].astype(int)

# %%
df.sample(5)
# Out:
#               Winner        Country  Distance (Miles)  Distance (KM)  Hour  \
# 11  Thomas Morrissey  United States              24.5           39.4     2
# 18   Lorraine Moller    New Zealand              26.2           42.2     2
# 77       Neil Cusack        Ireland              26.2           42.2     2
# 5    Sara Mae Berman  United States              26.2           42.2     3
# 57   Veikko Karvonen        Finland              25.7           41.4     2
#
#     Minutes  Second  year
# 11       25      43  1908
# 18       29      28  1984
# 77       13      39  1974
# 5         8      30  1971
# 57       20      39  1954

# %%
import seaborn as sns
import matplotlib as plt
# %matplotlib inline

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# C:\Users\21. Technology\AppData\Local\Temp\ipykernel_6904\529717881.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %%
cmap=sns.diverging_palette(230,20, as_cmap=True)
sns.heatmap(df.corr().describe(),annot=True,cmap='Dark2_r',linewidths=2)
# Out:
# C:\Users\21. Technology\AppData\Local\Temp\ipykernel_6904\485813340.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr().describe(),annot=True,cmap='Dark2_r',linewidths=2)
# <Axes: >

# %%
df.columns
# Out:
# Index(['Winner', 'Country', 'Distance (Miles)', 'Distance (KM)', 'Hour',
#        'Minutes', 'Second', 'year'],
#       dtype='object')

# %%
import pandas as pd
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
# %matplotlib inline
import seaborn as sns
import pandas as pd
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
for i in ['Winner', 'Country', 'Distance (Miles)', 'Distance (KM)', 'Hour',
       'Minutes', 'Second']:
    plt.figure(figsize=(15,9))
    sns.scatterplot(y=df.year,x=df[i],data=df,linewidth=1)
    plt.show()

# %%
sns.pairplot(data=df)

# %%
df.columns
# Out:
# Index(['Winner', 'Country', 'Distance (Miles)', 'Distance (KM)', 'Hour',
#        'Minutes', 'Second', 'year'],
#       dtype='object')

# %%
sns.lineplot(data=df)
# Out:
# <Axes: >

# %%
sns.lineplot(y='Country',x='year',data=df)
# Out:
# <Axes: xlabel='year', ylabel='Country'>

# %%
sns.lineplot(y='Country',x='year',data=df,hue='Hour')
# Out:
# <Axes: xlabel='year', ylabel='Country'>

# %%
for i in ['Winner', 'Country', 'Distance (Miles)', 'Distance (KM)', 'Hour',
       'Minutes', 'Second']:
    plt.figure(figsize=(15,9))
    sns.boxplot(y=df.year,x=df[i],data=df,linewidth=1)
    plt.show()

# %%
for i in ['Winner', 'Country', 'Distance (Miles)', 'Distance (KM)', 'Hour',
       'Minutes', 'Second']:
    plt.figure(figsize=(15,9))
    sns.boxenplot(y=df.year,x=df[i],data=df,linewidth=1)
    plt.show()

# %%
for i in ['Winner', 'Country', 'Distance (Miles)', 'Distance (KM)', 'Hour',
       'Minutes', 'Second']:
    plt.figure(figsize=(15,9))
    sns.barplot(y=df.year,x=df[i],data=df,linewidth=1)
    plt.show()

# %%
for i in ['Winner', 'Country', 'Distance (Miles)', 'Distance (KM)', 'Hour',
       'Minutes', 'Second']:
    plt.figure(figsize=(15,9))
    sns.displot(y=df.year,x=df[i],data=df,linewidth=1)
    plt.show()

# %%
sns.lmplot(data=df, x="Distance (Miles)", y="year")

# %%
sns.lmplot(data=df, x="Hour", y="Minutes", hue="Second")

# %%
df.columns
# Out:
# Index(['Winner', 'Country', 'Distance (Miles)', 'Distance (KM)', 'Hour',
#        'Minutes', 'Second', 'year'],
#       dtype='object')

# %%
sns.pointplot(data=df, x="Distance (Miles)", y="Distance (KM)", hue="Hour")
# Out:
# <Axes: xlabel='Distance (Miles)', ylabel='Distance (KM)'>

# %%
sns.jointplot(data=df, x="Distance (Miles)", y="Distance (KM)")

# %%
sns.jointplot(data=df, x="Distance (Miles)", y="Distance (KM)", hue="Hour")

# %%
sns.kdeplot(data=df, x="Distance (Miles)", hue="Distance (KM)", multiple="stack")
# Out:
# C:\Users\21. Technology\AppData\Local\Temp\ipykernel_6904\352333896.py:1: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=df, x="Distance (Miles)", hue="Distance (KM)", multiple="stack")
# <Axes: xlabel='Distance (Miles)', ylabel='Density'>

# %%
sns.stripplot(data=df, x="Distance (Miles)", y="Distance (KM)")
# Out:
# <Axes: xlabel='Distance (Miles)', ylabel='Distance (KM)'>

# %%
sns.violinplot(data=df,  x="Distance (Miles)", y="Distance (KM)")
# Out:
# <Axes: xlabel='Distance (Miles)', ylabel='Distance (KM)'>

# %%
g = sns.FacetGrid(df, col="Distance (Miles)",  row="Distance (KM)")
g.map_dataframe(sns.histplot, x="Hour")

# %%
sns.catplot(data=df, x="Distance (Miles)", y="Distance (KM)")

# %%
sns.swarmplot(data=df, x="Distance (Miles)", y="Distance (KM)")
# Out:
# C:\Users\21. Technology\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 34.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\21. Technology\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 88.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='Distance (Miles)', ylabel='Distance (KM)'>
# C:\Users\21. Technology\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\21. Technology\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 91.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# ...
